# %% [markdown]
# <a href="https://colab.research.google.com/github/pritiyadav888/Machine-Learning-Projects/blob/main/COMP262_Extracting_text_from_images_tesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In this notebook we will demonstrate how to use tesseract to extract text from images

# %% [markdown]
# ### How to download tesseract in Linux

# %%
pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14070 sha256=749fa004299be94526f619d85696551f2fe474ea41180edb18e5f52583678e1b
#   Stored in directory: /root/.cache/pip/wheels/a4/89/b9/3f11250225d0f90e5454fcc30fd1b7208db226850715aa9ace
# Successfully built pytesseract
# ...

# %%
import os
# if (os.name) != "nt":
#     print("Not using Windows")
#     !sudo apt install tesseract-ocr
# !pip install pytesseract==0.3.7

# %% [markdown]
# ### How to download tesseract in Windows
#
# 1. Install tesseract using windows installer available at: https://github.com/UB-Mannheim/tesseract/wiki
#
# 2. Note the tesseract path from the installation. Default installation path at the time of this edit was: C:\Users\USER\AppData\Local\Tesseract-OCR. It may change so please check the installation path.
#
# 3. pip install pytesseract
#
# 4. Set the tesseract path in the script before calling image_to_string.

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %%
#making the necessary imports
import pytesseract
from pytesseract import image_to_string
from PIL import Image

# # ONLY FOR WINDOWS USERS
# # Setting the tesseract path in the script before calling image_to_string.
# if (os.name) == "nt":
#     pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# ### For google colab users

# %%
# uploading an image into colab
try:
    from google.colab import files
    uploaded = files.upload()
except ModuleNotFoundError:
    print("Not using colab")
# Out:
#      <input type="file" id="files-edf58dc1-99e7-4d2d-a78b-a5eed71af8bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-edf58dc1-99e7-4d2d-a78b-a5eed71af8bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screen Shot 2022-01-21 at 12.51.57 AM.png to Screen Shot 2022-01-21 at 12.51.57 AM.png

# %% [markdown]
#   ### This is the original image

# %%
image0=Image.open('Screen Shot 2022-01-21 at 12.51.57 AM.png') 
image0
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2276x1024 at 0x7F179FD9E390>

# %%
# !apt-get install tesseract-ocr-hin
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-hin
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 912 kB of archives.
# After this operation, 1,138 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-hin all 4.00~git24-0e00fe6-1.2 [912 kB]
# Fetched 912 kB in 1s (1,182 kB/s)
# Selecting previously unselected package tesseract-ocr-hin.
# (Reading database ... 155276 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-hin_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-hin (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr-hin (4.00~git24-0e00fe6-1.2) ...

# %%
# !tesseract --list-langs
# Out:
# List of available languages (3):
# hin
# eng
# osd

# %%
image_path=r"Screen Shot 2022-01-21 at 12.51.57 AM.png"
extractedInformation = image_to_string(Image.open(image_path), lang = "hin")
extractedInformation
# Out:
# 'सब कुछ तुझपे हार गयी मैं\nखुद की खुद नहीं रही मैं\nओसजना\n\nहर तू मुझपे नज़र करे ना\nथोड़ी सी भी फ़िक्र करे ना\nमन्नत कर करके थक गयी मैं\nओ सजना\n\nलाखो का दिल तेरा\nये तेरा थंडर सा ठुमका\nअबनखरा ना कर तू\n\x0c'

# %% [markdown]
# As you can see the output is not perfect. An approach to make this better would be to include certain image pre processing steps before using tesseract
